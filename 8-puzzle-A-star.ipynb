# %%
import copy

def manhattan_distance(state, goal):
    # map each tile in goal to its (i,j) position
    goal_pos = {}
    for i in range(3):
        for j in range(3):
            goal_pos[goal[i][j]] = (i, j)

    dist = 0
    for i in range(3):
        for j in range(3):
            tile = state[i][j]
            if tile == '*':
                continue
            gi, gj = goal_pos[tile] # store the indexes of the tile in the goal state
            dist += abs(i - gi) + abs(j - gj)
    return dist


class Node:
    def __init__(self, state, g=0, h=0, parent=None):
        self.state = state      # puzzle configuration
        self.g = g              # cost so far
        self.h = h              # heuristic cost
        self.f = g + h          # f = g + h (A* score) [total cost]
        self.parent = parent    # reference to previous node

    def find(self):
        for i in range(3):
            for j in range(3):
                if self.state[i][j] == '*':
                    return i, j

    def move(self, x0, y0, x1, y1):
        if 0 <= x1 <= 2 and 0 <= y1 <= 2:
            tempstate = copy.deepcopy(self.state)
            tempstate[x0][y0], tempstate[x1][y1] = tempstate[x1][y1], tempstate[x0][y0]
            return tempstate
        return None

    # NOTE: generate returns children with g incremented; h will be computed later
    def generate(self, movement):
        x, y = self.find()
        if movement == 'r':
            new_state = self.move(x, y, x, y + 1)
        elif movement == 'l':
            new_state = self.move(x, y, x, y - 1)
        elif movement == 'u':
            new_state = self.move(x, y, x - 1, y)
        elif movement == 'd':
            new_state = self.move(x, y, x + 1, y)
        else:
            return None

        if new_state is not None:
            # create child node, increment g by 1, set parent to current node
            return Node(new_state, g=self.g + 1, parent=self)
        return None

    def __eq__(self, other):
        return isinstance(other, Node) and self.state == other.state

    def __repr__(self):
        return f"Node(f={self.f}, g={self.g}, h={self.h})"


class Puzzle:
    def __init__(self):
        self.open = []          # nodes to explore
        self.closed = []        # already explored nodes
        self.goal_state = None

    def read_input(self, filename="input.txt"):
        with open(filename, 'r') as file:
            lines = file.readlines()
            lines = [line.strip().split(" ") for line in lines]

        start_state = lines[1:4]
        goal_state = lines[5:8]
        self.goal_state = goal_state
        return start_state, goal_state


    def init_start_node(self, start_state, goal_state):
        g_s = 0
        h_s = manhattan_distance(start_state, goal_state)
        start = Node(start_state, g=g_s, h=h_s)
        self.open.append(start)

        print("Placed start node into OPEN.")
        self.display_node(start, "Start Node")


    def is_open_empty(self):
        if not self.open:
            print("Failure: OPEN list is empty. No solution exists.")
            return True
        return False
    

    def get_best_node(self):
        n = min(self.open, key=lambda node: node.f)
        self.open.remove(n)
        self.closed.append(n)
        print("\nSelected node with smallest f from OPEN:")
        self.display_node(n, "n")
        print(f"Moved n from OPEN to CLOSED.")
        print(f"OPEN size: {len(self.open)}, CLOSED size: {len(self.closed)}\n")
        return n


    def display_node(self, node, name="Node"):
        print(f"{name}:")
        for row in node.state:
            print(" ".join(row))
        print(f"g = {node.g}, h = {node.h}, f = {node.f}\n")

    def is_goal(self, node):
        return node.state == self.goal_state
    
    def reconstruct_path(self, node):
        path = []
        current = node

        while current:
            path.append(current)
            current = current.parent
        
        path.reverse()
        return path

    def display_solution(self, path):
        print("\nSolution Found!")
        print(f"Number of moves: {len(path) - 1}\n")

        for step, node in enumerate(path):
            print(f"Step {step} (g={node.g}, h={node.h}, f={node.f}):")
            for row in node.state:
                print(" ".join(row))
            print()
    
    def expand_node(self, node):
        children = []
        directions = ['r', 'l', 'u', 'd']

        for move in directions:
            child = node.generate(move)
            if child is not None:
                # compute heuristic for child
                child.h = manhattan_distance(child.state, self.goal_state)
                child.f = child.g + child.h
                children.append(child)
        return children
    
    def add_children_to_open(self, children, parent):
        for child in children:
            #Searching existing node in OPEN and CLOSED
            open_match = next((c for c in self.open if c.state == child.state), None)
            closed_match = next((c for c in self.closed if c.state == child.state), None)

            if open_match is None and closed_match is None:
                # add the new nodes to OPEN
                self.open.append(child)
                child.parent = parent
                print("Added child to OPEN:")
                self.display_node(child)
            else:
                # it already exists in OPEN or CLOSED
                existing = open_match if open_match else closed_match

                if child.f < existing.f:
                    print("Found a better path to an existing node:")
                    self.display_node(child)

                    # update existing node with better value
                    existing.g = child.g
                    existing.h = child.h
                    existing.f = child.f
                    existing.parent = parent

                    if closed_match:
                        # move it back to OPEN
                        self.closed.remove(existing)
                        self.open.append(existing)
                        print("Moved node from CLOSED back to OPEN with updated f")

    def start(self):
        start_state, goal_state = self.read_input("input.txt")

        # STEP 1: Initialize start node and put it in OPEN
        self.init_start_node(start_state, goal_state)

        #STEP 8: Loop until solution is found or failure
        while True:
            # STEP 2: Check if OPEN is empty
            if self.is_open_empty():
                return

            # STEP 3: Get node with smallest f from OPEN and move it to CLOSED
            n = self.get_best_node()

            # STEP 4: Check if n is the goal state
            if self.is_goal(n):
                path = self.reconstruct_path(n)
                self.display_solution(path)
                return
            else:
                print("n is not the goal state. Generating children...\n")

            # STEP 5: Expand node n, generate all children
            children = self.expand_node(n)

            if not children:
                print("No successors for this node. Returning to Step 2...\n")
                return
            else:
                print(f"Generated {len(children)} successors of n:\n")
                for idx, child in enumerate(children):
                    print(f"Child {idx + 1}:")
                    for row in child.state:
                        print(" ".join(row))
                    print(f"g = {child.g}, h = {child.h}, f = {child.f}\n")
        
            #STEP 6 and 7: Insert children or update existing nodes
            self.add_children_to_open(children, n)


if __name__ == "__main__":
    p = Puzzle()
    p.start()
# Out:
# Placed start node into OPEN.
# Start Node:
# 2 1 6
# 4 * 8
# 7 5 3
# g = 0, h = 12, f = 12
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 4 * 8
# 7 5 3
# g = 0, h = 12, f = 12
#
# Moved n from OPEN to CLOSED.
# OPEN size: 0, CLOSED size: 1
#
# n is not the goal state. Generating children...
#
# Generated 4 successors of n:
#
# Child 1:
# 2 1 6
# 4 8 *
# 7 5 3
# g = 1, h = 11, f = 12
#
# Child 2:
# 2 1 6
# * 4 8
# 7 5 3
# g = 1, h = 11, f = 12
#
# Child 3:
# 2 * 6
# 4 1 8
# 7 5 3
# g = 1, h = 13, f = 14
#
# Child 4:
# 2 1 6
# 4 5 8
# 7 * 3
# g = 1, h = 13, f = 14
#
# Added child to OPEN:
# Node:
# 2 1 6
# 4 8 *
# 7 5 3
# g = 1, h = 11, f = 12
#
# Added child to OPEN:
# Node:
# 2 1 6
# * 4 8
# 7 5 3
# g = 1, h = 11, f = 12
#
# Added child to OPEN:
# Node:
# 2 * 6
# 4 1 8
# 7 5 3
# g = 1, h = 13, f = 14
#
# Added child to OPEN:
# Node:
# 2 1 6
# 4 5 8
# 7 * 3
# g = 1, h = 13, f = 14
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 4 8 *
# 7 5 3
# g = 1, h = 11, f = 12
#
# Moved n from OPEN to CLOSED.
# OPEN size: 3, CLOSED size: 2
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 6
# 4 * 8
# 7 5 3
# g = 2, h = 12, f = 14
#
# Child 2:
# 2 1 *
# 4 8 6
# 7 5 3
# g = 2, h = 10, f = 12
#
# Child 3:
# 2 1 6
# 4 8 3
# 7 5 *
# g = 2, h = 10, f = 12
#
# Added child to OPEN:
# Node:
# 2 1 *
# 4 8 6
# 7 5 3
# g = 2, h = 10, f = 12
#
# Added child to OPEN:
# Node:
# 2 1 6
# 4 8 3
# 7 5 *
# g = 2, h = 10, f = 12
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# * 4 8
# 7 5 3
# g = 1, h = 11, f = 12
#
# Moved n from OPEN to CLOSED.
# OPEN size: 4, CLOSED size: 3
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 6
# 4 * 8
# 7 5 3
# g = 2, h = 12, f = 14
#
# Child 2:
# * 1 6
# 2 4 8
# 7 5 3
# g = 2, h = 12, f = 14
#
# Child 3:
# 2 1 6
# 7 4 8
# * 5 3
# g = 2, h = 12, f = 14
#
# Added child to OPEN:
# Node:
# * 1 6
# 2 4 8
# 7 5 3
# g = 2, h = 12, f = 14
#
# Added child to OPEN:
# Node:
# 2 1 6
# 7 4 8
# * 5 3
# g = 2, h = 12, f = 14
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 *
# 4 8 6
# 7 5 3
# g = 2, h = 10, f = 12
#
# Moved n from OPEN to CLOSED.
# OPEN size: 5, CLOSED size: 4
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 * 1
# 4 8 6
# 7 5 3
# g = 3, h = 11, f = 14
#
# Child 2:
# 2 1 6
# 4 8 *
# 7 5 3
# g = 3, h = 11, f = 14
#
# Added child to OPEN:
# Node:
# 2 * 1
# 4 8 6
# 7 5 3
# g = 3, h = 11, f = 14
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 4 8 3
# 7 5 *
# g = 2, h = 10, f = 12
#
# Moved n from OPEN to CLOSED.
# OPEN size: 5, CLOSED size: 5
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 1 6
# 4 8 3
# 7 * 5
# g = 3, h = 9, f = 12
#
# Child 2:
# 2 1 6
# 4 8 *
# 7 5 3
# g = 3, h = 11, f = 14
#
# Added child to OPEN:
# Node:
# 2 1 6
# 4 8 3
# 7 * 5
# g = 3, h = 9, f = 12
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 4 8 3
# 7 * 5
# g = 3, h = 9, f = 12
#
# Moved n from OPEN to CLOSED.
# OPEN size: 5, CLOSED size: 6
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 6
# 4 8 3
# 7 5 *
# g = 4, h = 10, f = 14
#
# Child 2:
# 2 1 6
# 4 8 3
# * 7 5
# g = 4, h = 10, f = 14
#
# Child 3:
# 2 1 6
# 4 * 3
# 7 8 5
# g = 4, h = 10, f = 14
#
# Added child to OPEN:
# Node:
# 2 1 6
# 4 8 3
# * 7 5
# g = 4, h = 10, f = 14
#
# Added child to OPEN:
# Node:
# 2 1 6
# 4 * 3
# 7 8 5
# g = 4, h = 10, f = 14
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 * 6
# 4 1 8
# 7 5 3
# g = 1, h = 13, f = 14
#
# Moved n from OPEN to CLOSED.
# OPEN size: 6, CLOSED size: 7
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 6 *
# 4 1 8
# 7 5 3
# g = 2, h = 12, f = 14
#
# Child 2:
# * 2 6
# 4 1 8
# 7 5 3
# g = 2, h = 12, f = 14
#
# Child 3:
# 2 1 6
# 4 * 8
# 7 5 3
# g = 2, h = 12, f = 14
#
# Added child to OPEN:
# Node:
# 2 6 *
# 4 1 8
# 7 5 3
# g = 2, h = 12, f = 14
#
# Added child to OPEN:
# Node:
# * 2 6
# 4 1 8
# 7 5 3
# g = 2, h = 12, f = 14
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 4 5 8
# 7 * 3
# g = 1, h = 13, f = 14
#
# Moved n from OPEN to CLOSED.
# OPEN size: 7, CLOSED size: 8
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 6
# 4 5 8
# 7 3 *
# g = 2, h = 14, f = 16
#
# Child 2:
# 2 1 6
# 4 5 8
# * 7 3
# g = 2, h = 14, f = 16
#
# Child 3:
# 2 1 6
# 4 * 8
# 7 5 3
# g = 2, h = 12, f = 14
#
# Added child to OPEN:
# Node:
# 2 1 6
# 4 5 8
# 7 3 *
# g = 2, h = 14, f = 16
#
# Added child to OPEN:
# Node:
# 2 1 6
# 4 5 8
# * 7 3
# g = 2, h = 14, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# * 1 6
# 2 4 8
# 7 5 3
# g = 2, h = 12, f = 14
#
# Moved n from OPEN to CLOSED.
# OPEN size: 8, CLOSED size: 9
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 1 * 6
# 2 4 8
# 7 5 3
# g = 3, h = 11, f = 14
#
# Child 2:
# 2 1 6
# * 4 8
# 7 5 3
# g = 3, h = 11, f = 14
#
# Added child to OPEN:
# Node:
# 1 * 6
# 2 4 8
# 7 5 3
# g = 3, h = 11, f = 14
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 7 4 8
# * 5 3
# g = 2, h = 12, f = 14
#
# Moved n from OPEN to CLOSED.
# OPEN size: 8, CLOSED size: 10
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 1 6
# 7 4 8
# 5 * 3
# g = 3, h = 13, f = 16
#
# Child 2:
# 2 1 6
# * 4 8
# 7 5 3
# g = 3, h = 11, f = 14
#
# Added child to OPEN:
# Node:
# 2 1 6
# 7 4 8
# 5 * 3
# g = 3, h = 13, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 * 1
# 4 8 6
# 7 5 3
# g = 3, h = 11, f = 14
#
# Moved n from OPEN to CLOSED.
# OPEN size: 8, CLOSED size: 11
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 *
# 4 8 6
# 7 5 3
# g = 4, h = 10, f = 14
#
# Child 2:
# * 2 1
# 4 8 6
# 7 5 3
# g = 4, h = 10, f = 14
#
# Child 3:
# 2 8 1
# 4 * 6
# 7 5 3
# g = 4, h = 12, f = 16
#
# Added child to OPEN:
# Node:
# * 2 1
# 4 8 6
# 7 5 3
# g = 4, h = 10, f = 14
#
# Added child to OPEN:
# Node:
# 2 8 1
# 4 * 6
# 7 5 3
# g = 4, h = 12, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 4 8 3
# * 7 5
# g = 4, h = 10, f = 14
#
# Moved n from OPEN to CLOSED.
# OPEN size: 9, CLOSED size: 12
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 1 6
# 4 8 3
# 7 * 5
# g = 5, h = 9, f = 14
#
# Child 2:
# 2 1 6
# * 8 3
# 4 7 5
# g = 5, h = 11, f = 16
#
# Added child to OPEN:
# Node:
# 2 1 6
# * 8 3
# 4 7 5
# g = 5, h = 11, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 4 * 3
# 7 8 5
# g = 4, h = 10, f = 14
#
# Moved n from OPEN to CLOSED.
# OPEN size: 9, CLOSED size: 13
#
# n is not the goal state. Generating children...
#
# Generated 4 successors of n:
#
# Child 1:
# 2 1 6
# 4 3 *
# 7 8 5
# g = 5, h = 11, f = 16
#
# Child 2:
# 2 1 6
# * 4 3
# 7 8 5
# g = 5, h = 9, f = 14
#
# Child 3:
# 2 * 6
# 4 1 3
# 7 8 5
# g = 5, h = 11, f = 16
#
# Child 4:
# 2 1 6
# 4 8 3
# 7 * 5
# g = 5, h = 9, f = 14
#
# Added child to OPEN:
# Node:
# 2 1 6
# 4 3 *
# 7 8 5
# g = 5, h = 11, f = 16
#
# Added child to OPEN:
# Node:
# 2 1 6
# * 4 3
# 7 8 5
# g = 5, h = 9, f = 14
#
# Added child to OPEN:
# Node:
# 2 * 6
# 4 1 3
# 7 8 5
# g = 5, h = 11, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 6 *
# 4 1 8
# 7 5 3
# g = 2, h = 12, f = 14
#
# Moved n from OPEN to CLOSED.
# OPEN size: 11, CLOSED size: 14
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 * 6
# 4 1 8
# 7 5 3
# g = 3, h = 13, f = 16
#
# Child 2:
# 2 6 8
# 4 1 *
# 7 5 3
# g = 3, h = 13, f = 16
#
# Added child to OPEN:
# Node:
# 2 6 8
# 4 1 *
# 7 5 3
# g = 3, h = 13, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# * 2 6
# 4 1 8
# 7 5 3
# g = 2, h = 12, f = 14
#
# Moved n from OPEN to CLOSED.
# OPEN size: 11, CLOSED size: 15
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 * 6
# 4 1 8
# 7 5 3
# g = 3, h = 13, f = 16
#
# Child 2:
# 4 2 6
# * 1 8
# 7 5 3
# g = 3, h = 13, f = 16
#
# Added child to OPEN:
# Node:
# 4 2 6
# * 1 8
# 7 5 3
# g = 3, h = 13, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 * 6
# 2 4 8
# 7 5 3
# g = 3, h = 11, f = 14
#
# Moved n from OPEN to CLOSED.
# OPEN size: 11, CLOSED size: 16
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 6 *
# 2 4 8
# 7 5 3
# g = 4, h = 10, f = 14
#
# Child 2:
# * 1 6
# 2 4 8
# 7 5 3
# g = 4, h = 12, f = 16
#
# Child 3:
# 1 4 6
# 2 * 8
# 7 5 3
# g = 4, h = 12, f = 16
#
# Added child to OPEN:
# Node:
# 1 6 *
# 2 4 8
# 7 5 3
# g = 4, h = 10, f = 14
#
# Added child to OPEN:
# Node:
# 1 4 6
# 2 * 8
# 7 5 3
# g = 4, h = 12, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# * 2 1
# 4 8 6
# 7 5 3
# g = 4, h = 10, f = 14
#
# Moved n from OPEN to CLOSED.
# OPEN size: 12, CLOSED size: 17
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 * 1
# 4 8 6
# 7 5 3
# g = 5, h = 11, f = 16
#
# Child 2:
# 4 2 1
# * 8 6
# 7 5 3
# g = 5, h = 11, f = 16
#
# Added child to OPEN:
# Node:
# 4 2 1
# * 8 6
# 7 5 3
# g = 5, h = 11, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# * 4 3
# 7 8 5
# g = 5, h = 9, f = 14
#
# Moved n from OPEN to CLOSED.
# OPEN size: 12, CLOSED size: 18
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 6
# 4 * 3
# 7 8 5
# g = 6, h = 10, f = 16
#
# Child 2:
# * 1 6
# 2 4 3
# 7 8 5
# g = 6, h = 10, f = 16
#
# Child 3:
# 2 1 6
# 7 4 3
# * 8 5
# g = 6, h = 10, f = 16
#
# Added child to OPEN:
# Node:
# * 1 6
# 2 4 3
# 7 8 5
# g = 6, h = 10, f = 16
#
# Added child to OPEN:
# Node:
# 2 1 6
# 7 4 3
# * 8 5
# g = 6, h = 10, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 6 *
# 2 4 8
# 7 5 3
# g = 4, h = 10, f = 14
#
# Moved n from OPEN to CLOSED.
# OPEN size: 13, CLOSED size: 19
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 1 * 6
# 2 4 8
# 7 5 3
# g = 5, h = 11, f = 16
#
# Child 2:
# 1 6 8
# 2 4 *
# 7 5 3
# g = 5, h = 11, f = 16
#
# Added child to OPEN:
# Node:
# 1 6 8
# 2 4 *
# 7 5 3
# g = 5, h = 11, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 4 5 8
# 7 3 *
# g = 2, h = 14, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 13, CLOSED size: 20
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 1 6
# 4 5 8
# 7 * 3
# g = 3, h = 13, f = 16
#
# Child 2:
# 2 1 6
# 4 5 *
# 7 3 8
# g = 3, h = 15, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 6
# 4 5 *
# 7 3 8
# g = 3, h = 15, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 4 5 8
# * 7 3
# g = 2, h = 14, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 13, CLOSED size: 21
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 1 6
# 4 5 8
# 7 * 3
# g = 3, h = 13, f = 16
#
# Child 2:
# 2 1 6
# * 5 8
# 4 7 3
# g = 3, h = 15, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 6
# * 5 8
# 4 7 3
# g = 3, h = 15, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 7 4 8
# 5 * 3
# g = 3, h = 13, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 13, CLOSED size: 22
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 6
# 7 4 8
# 5 3 *
# g = 4, h = 14, f = 18
#
# Child 2:
# 2 1 6
# 7 4 8
# * 5 3
# g = 4, h = 12, f = 16
#
# Child 3:
# 2 1 6
# 7 * 8
# 5 4 3
# g = 4, h = 14, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 6
# 7 4 8
# 5 3 *
# g = 4, h = 14, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 6
# 7 * 8
# 5 4 3
# g = 4, h = 14, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 8 1
# 4 * 6
# 7 5 3
# g = 4, h = 12, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 14, CLOSED size: 23
#
# n is not the goal state. Generating children...
#
# Generated 4 successors of n:
#
# Child 1:
# 2 8 1
# 4 6 *
# 7 5 3
# g = 5, h = 11, f = 16
#
# Child 2:
# 2 8 1
# * 4 6
# 7 5 3
# g = 5, h = 11, f = 16
#
# Child 3:
# 2 * 1
# 4 8 6
# 7 5 3
# g = 5, h = 11, f = 16
#
# Child 4:
# 2 8 1
# 4 5 6
# 7 * 3
# g = 5, h = 13, f = 18
#
# Added child to OPEN:
# Node:
# 2 8 1
# 4 6 *
# 7 5 3
# g = 5, h = 11, f = 16
#
# Added child to OPEN:
# Node:
# 2 8 1
# * 4 6
# 7 5 3
# g = 5, h = 11, f = 16
#
# Added child to OPEN:
# Node:
# 2 8 1
# 4 5 6
# 7 * 3
# g = 5, h = 13, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# * 8 3
# 4 7 5
# g = 5, h = 11, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 16, CLOSED size: 24
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 6
# 8 * 3
# 4 7 5
# g = 6, h = 10, f = 16
#
# Child 2:
# * 1 6
# 2 8 3
# 4 7 5
# g = 6, h = 12, f = 18
#
# Child 3:
# 2 1 6
# 4 8 3
# * 7 5
# g = 6, h = 10, f = 16
#
# Added child to OPEN:
# Node:
# 2 1 6
# 8 * 3
# 4 7 5
# g = 6, h = 10, f = 16
#
# Added child to OPEN:
# Node:
# * 1 6
# 2 8 3
# 4 7 5
# g = 6, h = 12, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 4 3 *
# 7 8 5
# g = 5, h = 11, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 17, CLOSED size: 25
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 6
# 4 * 3
# 7 8 5
# g = 6, h = 10, f = 16
#
# Child 2:
# 2 1 *
# 4 3 6
# 7 8 5
# g = 6, h = 10, f = 16
#
# Child 3:
# 2 1 6
# 4 3 5
# 7 8 *
# g = 6, h = 12, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 *
# 4 3 6
# 7 8 5
# g = 6, h = 10, f = 16
#
# Added child to OPEN:
# Node:
# 2 1 6
# 4 3 5
# 7 8 *
# g = 6, h = 12, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 * 6
# 4 1 3
# 7 8 5
# g = 5, h = 11, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 18, CLOSED size: 26
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 6 *
# 4 1 3
# 7 8 5
# g = 6, h = 10, f = 16
#
# Child 2:
# * 2 6
# 4 1 3
# 7 8 5
# g = 6, h = 10, f = 16
#
# Child 3:
# 2 1 6
# 4 * 3
# 7 8 5
# g = 6, h = 10, f = 16
#
# Added child to OPEN:
# Node:
# 2 6 *
# 4 1 3
# 7 8 5
# g = 6, h = 10, f = 16
#
# Added child to OPEN:
# Node:
# * 2 6
# 4 1 3
# 7 8 5
# g = 6, h = 10, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 6 8
# 4 1 *
# 7 5 3
# g = 3, h = 13, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 19, CLOSED size: 27
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 6 8
# 4 * 1
# 7 5 3
# g = 4, h = 14, f = 18
#
# Child 2:
# 2 6 *
# 4 1 8
# 7 5 3
# g = 4, h = 12, f = 16
#
# Child 3:
# 2 6 8
# 4 1 3
# 7 5 *
# g = 4, h = 12, f = 16
#
# Added child to OPEN:
# Node:
# 2 6 8
# 4 * 1
# 7 5 3
# g = 4, h = 14, f = 18
#
# Added child to OPEN:
# Node:
# 2 6 8
# 4 1 3
# 7 5 *
# g = 4, h = 12, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 4 2 6
# * 1 8
# 7 5 3
# g = 3, h = 13, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 20, CLOSED size: 28
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 4 2 6
# 1 * 8
# 7 5 3
# g = 4, h = 12, f = 16
#
# Child 2:
# * 2 6
# 4 1 8
# 7 5 3
# g = 4, h = 12, f = 16
#
# Child 3:
# 4 2 6
# 7 1 8
# * 5 3
# g = 4, h = 14, f = 18
#
# Added child to OPEN:
# Node:
# 4 2 6
# 1 * 8
# 7 5 3
# g = 4, h = 12, f = 16
#
# Added child to OPEN:
# Node:
# 4 2 6
# 7 1 8
# * 5 3
# g = 4, h = 14, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 4 6
# 2 * 8
# 7 5 3
# g = 4, h = 12, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 21, CLOSED size: 29
#
# n is not the goal state. Generating children...
#
# Generated 4 successors of n:
#
# Child 1:
# 1 4 6
# 2 8 *
# 7 5 3
# g = 5, h = 11, f = 16
#
# Child 2:
# 1 4 6
# * 2 8
# 7 5 3
# g = 5, h = 11, f = 16
#
# Child 3:
# 1 * 6
# 2 4 8
# 7 5 3
# g = 5, h = 11, f = 16
#
# Child 4:
# 1 4 6
# 2 5 8
# 7 * 3
# g = 5, h = 13, f = 18
#
# Added child to OPEN:
# Node:
# 1 4 6
# 2 8 *
# 7 5 3
# g = 5, h = 11, f = 16
#
# Added child to OPEN:
# Node:
# 1 4 6
# * 2 8
# 7 5 3
# g = 5, h = 11, f = 16
#
# Added child to OPEN:
# Node:
# 1 4 6
# 2 5 8
# 7 * 3
# g = 5, h = 13, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 4 2 1
# * 8 6
# 7 5 3
# g = 5, h = 11, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 23, CLOSED size: 30
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 4 2 1
# 8 * 6
# 7 5 3
# g = 6, h = 10, f = 16
#
# Child 2:
# * 2 1
# 4 8 6
# 7 5 3
# g = 6, h = 10, f = 16
#
# Child 3:
# 4 2 1
# 7 8 6
# * 5 3
# g = 6, h = 12, f = 18
#
# Added child to OPEN:
# Node:
# 4 2 1
# 8 * 6
# 7 5 3
# g = 6, h = 10, f = 16
#
# Added child to OPEN:
# Node:
# 4 2 1
# 7 8 6
# * 5 3
# g = 6, h = 12, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# * 1 6
# 2 4 3
# 7 8 5
# g = 6, h = 10, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 24, CLOSED size: 31
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 1 * 6
# 2 4 3
# 7 8 5
# g = 7, h = 9, f = 16
#
# Child 2:
# 2 1 6
# * 4 3
# 7 8 5
# g = 7, h = 9, f = 16
#
# Added child to OPEN:
# Node:
# 1 * 6
# 2 4 3
# 7 8 5
# g = 7, h = 9, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 7 4 3
# * 8 5
# g = 6, h = 10, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 24, CLOSED size: 32
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 1 6
# 7 4 3
# 8 * 5
# g = 7, h = 9, f = 16
#
# Child 2:
# 2 1 6
# * 4 3
# 7 8 5
# g = 7, h = 9, f = 16
#
# Added child to OPEN:
# Node:
# 2 1 6
# 7 4 3
# 8 * 5
# g = 7, h = 9, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 6 8
# 2 4 *
# 7 5 3
# g = 5, h = 11, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 24, CLOSED size: 33
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 6 8
# 2 * 4
# 7 5 3
# g = 6, h = 10, f = 16
#
# Child 2:
# 1 6 *
# 2 4 8
# 7 5 3
# g = 6, h = 10, f = 16
#
# Child 3:
# 1 6 8
# 2 4 3
# 7 5 *
# g = 6, h = 10, f = 16
#
# Added child to OPEN:
# Node:
# 1 6 8
# 2 * 4
# 7 5 3
# g = 6, h = 10, f = 16
#
# Added child to OPEN:
# Node:
# 1 6 8
# 2 4 3
# 7 5 *
# g = 6, h = 10, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 8 1
# 4 6 *
# 7 5 3
# g = 5, h = 11, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 25, CLOSED size: 34
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 8 1
# 4 * 6
# 7 5 3
# g = 6, h = 12, f = 18
#
# Child 2:
# 2 8 *
# 4 6 1
# 7 5 3
# g = 6, h = 12, f = 18
#
# Child 3:
# 2 8 1
# 4 6 3
# 7 5 *
# g = 6, h = 10, f = 16
#
# Added child to OPEN:
# Node:
# 2 8 *
# 4 6 1
# 7 5 3
# g = 6, h = 12, f = 18
#
# Added child to OPEN:
# Node:
# 2 8 1
# 4 6 3
# 7 5 *
# g = 6, h = 10, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 8 1
# * 4 6
# 7 5 3
# g = 5, h = 11, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 26, CLOSED size: 35
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 8 1
# 4 * 6
# 7 5 3
# g = 6, h = 12, f = 18
#
# Child 2:
# * 8 1
# 2 4 6
# 7 5 3
# g = 6, h = 12, f = 18
#
# Child 3:
# 2 8 1
# 7 4 6
# * 5 3
# g = 6, h = 12, f = 18
#
# Added child to OPEN:
# Node:
# * 8 1
# 2 4 6
# 7 5 3
# g = 6, h = 12, f = 18
#
# Added child to OPEN:
# Node:
# 2 8 1
# 7 4 6
# * 5 3
# g = 6, h = 12, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 8 * 3
# 4 7 5
# g = 6, h = 10, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 27, CLOSED size: 36
#
# n is not the goal state. Generating children...
#
# Generated 4 successors of n:
#
# Child 1:
# 2 1 6
# 8 3 *
# 4 7 5
# g = 7, h = 11, f = 18
#
# Child 2:
# 2 1 6
# * 8 3
# 4 7 5
# g = 7, h = 11, f = 18
#
# Child 3:
# 2 * 6
# 8 1 3
# 4 7 5
# g = 7, h = 11, f = 18
#
# Child 4:
# 2 1 6
# 8 7 3
# 4 * 5
# g = 7, h = 11, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 6
# 8 3 *
# 4 7 5
# g = 7, h = 11, f = 18
#
# Added child to OPEN:
# Node:
# 2 * 6
# 8 1 3
# 4 7 5
# g = 7, h = 11, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 6
# 8 7 3
# 4 * 5
# g = 7, h = 11, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 *
# 4 3 6
# 7 8 5
# g = 6, h = 10, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 29, CLOSED size: 37
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 * 1
# 4 3 6
# 7 8 5
# g = 7, h = 11, f = 18
#
# Child 2:
# 2 1 6
# 4 3 *
# 7 8 5
# g = 7, h = 11, f = 18
#
# Added child to OPEN:
# Node:
# 2 * 1
# 4 3 6
# 7 8 5
# g = 7, h = 11, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 6 *
# 4 1 3
# 7 8 5
# g = 6, h = 10, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 29, CLOSED size: 38
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 * 6
# 4 1 3
# 7 8 5
# g = 7, h = 11, f = 18
#
# Child 2:
# 2 6 3
# 4 1 *
# 7 8 5
# g = 7, h = 9, f = 16
#
# Added child to OPEN:
# Node:
# 2 6 3
# 4 1 *
# 7 8 5
# g = 7, h = 9, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# * 2 6
# 4 1 3
# 7 8 5
# g = 6, h = 10, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 29, CLOSED size: 39
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 * 6
# 4 1 3
# 7 8 5
# g = 7, h = 11, f = 18
#
# Child 2:
# 4 2 6
# * 1 3
# 7 8 5
# g = 7, h = 11, f = 18
#
# Added child to OPEN:
# Node:
# 4 2 6
# * 1 3
# 7 8 5
# g = 7, h = 11, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 6 8
# 4 1 3
# 7 5 *
# g = 4, h = 12, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 29, CLOSED size: 40
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 6 8
# 4 1 3
# 7 * 5
# g = 5, h = 11, f = 16
#
# Child 2:
# 2 6 8
# 4 1 *
# 7 5 3
# g = 5, h = 13, f = 18
#
# Added child to OPEN:
# Node:
# 2 6 8
# 4 1 3
# 7 * 5
# g = 5, h = 11, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 4 2 6
# 1 * 8
# 7 5 3
# g = 4, h = 12, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 29, CLOSED size: 41
#
# n is not the goal state. Generating children...
#
# Generated 4 successors of n:
#
# Child 1:
# 4 2 6
# 1 8 *
# 7 5 3
# g = 5, h = 11, f = 16
#
# Child 2:
# 4 2 6
# * 1 8
# 7 5 3
# g = 5, h = 13, f = 18
#
# Child 3:
# 4 * 6
# 1 2 8
# 7 5 3
# g = 5, h = 13, f = 18
#
# Child 4:
# 4 2 6
# 1 5 8
# 7 * 3
# g = 5, h = 13, f = 18
#
# Added child to OPEN:
# Node:
# 4 2 6
# 1 8 *
# 7 5 3
# g = 5, h = 11, f = 16
#
# Added child to OPEN:
# Node:
# 4 * 6
# 1 2 8
# 7 5 3
# g = 5, h = 13, f = 18
#
# Added child to OPEN:
# Node:
# 4 2 6
# 1 5 8
# 7 * 3
# g = 5, h = 13, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 4 6
# 2 8 *
# 7 5 3
# g = 5, h = 11, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 31, CLOSED size: 42
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 4 6
# 2 * 8
# 7 5 3
# g = 6, h = 12, f = 18
#
# Child 2:
# 1 4 *
# 2 8 6
# 7 5 3
# g = 6, h = 10, f = 16
#
# Child 3:
# 1 4 6
# 2 8 3
# 7 5 *
# g = 6, h = 10, f = 16
#
# Added child to OPEN:
# Node:
# 1 4 *
# 2 8 6
# 7 5 3
# g = 6, h = 10, f = 16
#
# Added child to OPEN:
# Node:
# 1 4 6
# 2 8 3
# 7 5 *
# g = 6, h = 10, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 4 6
# * 2 8
# 7 5 3
# g = 5, h = 11, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 32, CLOSED size: 43
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 4 6
# 2 * 8
# 7 5 3
# g = 6, h = 12, f = 18
#
# Child 2:
# * 4 6
# 1 2 8
# 7 5 3
# g = 6, h = 12, f = 18
#
# Child 3:
# 1 4 6
# 7 2 8
# * 5 3
# g = 6, h = 12, f = 18
#
# Added child to OPEN:
# Node:
# * 4 6
# 1 2 8
# 7 5 3
# g = 6, h = 12, f = 18
#
# Added child to OPEN:
# Node:
# 1 4 6
# 7 2 8
# * 5 3
# g = 6, h = 12, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 4 2 1
# 8 * 6
# 7 5 3
# g = 6, h = 10, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 33, CLOSED size: 44
#
# n is not the goal state. Generating children...
#
# Generated 4 successors of n:
#
# Child 1:
# 4 2 1
# 8 6 *
# 7 5 3
# g = 7, h = 9, f = 16
#
# Child 2:
# 4 2 1
# * 8 6
# 7 5 3
# g = 7, h = 11, f = 18
#
# Child 3:
# 4 * 1
# 8 2 6
# 7 5 3
# g = 7, h = 11, f = 18
#
# Child 4:
# 4 2 1
# 8 5 6
# 7 * 3
# g = 7, h = 11, f = 18
#
# Added child to OPEN:
# Node:
# 4 2 1
# 8 6 *
# 7 5 3
# g = 7, h = 9, f = 16
#
# Added child to OPEN:
# Node:
# 4 * 1
# 8 2 6
# 7 5 3
# g = 7, h = 11, f = 18
#
# Added child to OPEN:
# Node:
# 4 2 1
# 8 5 6
# 7 * 3
# g = 7, h = 11, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 * 6
# 2 4 3
# 7 8 5
# g = 7, h = 9, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 35, CLOSED size: 45
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 6 *
# 2 4 3
# 7 8 5
# g = 8, h = 8, f = 16
#
# Child 2:
# * 1 6
# 2 4 3
# 7 8 5
# g = 8, h = 10, f = 18
#
# Child 3:
# 1 4 6
# 2 * 3
# 7 8 5
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 1 6 *
# 2 4 3
# 7 8 5
# g = 8, h = 8, f = 16
#
# Added child to OPEN:
# Node:
# 1 4 6
# 2 * 3
# 7 8 5
# g = 8, h = 10, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 7 4 3
# 8 * 5
# g = 7, h = 9, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 36, CLOSED size: 46
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 6
# 7 4 3
# 8 5 *
# g = 8, h = 10, f = 18
#
# Child 2:
# 2 1 6
# 7 4 3
# * 8 5
# g = 8, h = 10, f = 18
#
# Child 3:
# 2 1 6
# 7 * 3
# 8 4 5
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 6
# 7 4 3
# 8 5 *
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 6
# 7 * 3
# 8 4 5
# g = 8, h = 10, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 6 8
# 2 * 4
# 7 5 3
# g = 6, h = 10, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 37, CLOSED size: 47
#
# n is not the goal state. Generating children...
#
# Generated 4 successors of n:
#
# Child 1:
# 1 6 8
# 2 4 *
# 7 5 3
# g = 7, h = 11, f = 18
#
# Child 2:
# 1 6 8
# * 2 4
# 7 5 3
# g = 7, h = 9, f = 16
#
# Child 3:
# 1 * 8
# 2 6 4
# 7 5 3
# g = 7, h = 9, f = 16
#
# Child 4:
# 1 6 8
# 2 5 4
# 7 * 3
# g = 7, h = 11, f = 18
#
# Added child to OPEN:
# Node:
# 1 6 8
# * 2 4
# 7 5 3
# g = 7, h = 9, f = 16
#
# Added child to OPEN:
# Node:
# 1 * 8
# 2 6 4
# 7 5 3
# g = 7, h = 9, f = 16
#
# Added child to OPEN:
# Node:
# 1 6 8
# 2 5 4
# 7 * 3
# g = 7, h = 11, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 6 8
# 2 4 3
# 7 5 *
# g = 6, h = 10, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 39, CLOSED size: 48
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 1 6 8
# 2 4 3
# 7 * 5
# g = 7, h = 9, f = 16
#
# Child 2:
# 1 6 8
# 2 4 *
# 7 5 3
# g = 7, h = 11, f = 18
#
# Added child to OPEN:
# Node:
# 1 6 8
# 2 4 3
# 7 * 5
# g = 7, h = 9, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 8 1
# 4 6 3
# 7 5 *
# g = 6, h = 10, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 39, CLOSED size: 49
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 8 1
# 4 6 3
# 7 * 5
# g = 7, h = 9, f = 16
#
# Child 2:
# 2 8 1
# 4 6 *
# 7 5 3
# g = 7, h = 11, f = 18
#
# Added child to OPEN:
# Node:
# 2 8 1
# 4 6 3
# 7 * 5
# g = 7, h = 9, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 6 3
# 4 1 *
# 7 8 5
# g = 7, h = 9, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 39, CLOSED size: 50
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 6 3
# 4 * 1
# 7 8 5
# g = 8, h = 10, f = 18
#
# Child 2:
# 2 6 *
# 4 1 3
# 7 8 5
# g = 8, h = 10, f = 18
#
# Child 3:
# 2 6 3
# 4 1 5
# 7 8 *
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 2 6 3
# 4 * 1
# 7 8 5
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 2 6 3
# 4 1 5
# 7 8 *
# g = 8, h = 10, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 6 8
# 4 1 3
# 7 * 5
# g = 5, h = 11, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 40, CLOSED size: 51
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 6 8
# 4 1 3
# 7 5 *
# g = 6, h = 12, f = 18
#
# Child 2:
# 2 6 8
# 4 1 3
# * 7 5
# g = 6, h = 12, f = 18
#
# Child 3:
# 2 6 8
# 4 * 3
# 7 1 5
# g = 6, h = 12, f = 18
#
# Added child to OPEN:
# Node:
# 2 6 8
# 4 1 3
# * 7 5
# g = 6, h = 12, f = 18
#
# Added child to OPEN:
# Node:
# 2 6 8
# 4 * 3
# 7 1 5
# g = 6, h = 12, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 4 2 6
# 1 8 *
# 7 5 3
# g = 5, h = 11, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 41, CLOSED size: 52
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 4 2 6
# 1 * 8
# 7 5 3
# g = 6, h = 12, f = 18
#
# Child 2:
# 4 2 *
# 1 8 6
# 7 5 3
# g = 6, h = 10, f = 16
#
# Child 3:
# 4 2 6
# 1 8 3
# 7 5 *
# g = 6, h = 10, f = 16
#
# Added child to OPEN:
# Node:
# 4 2 *
# 1 8 6
# 7 5 3
# g = 6, h = 10, f = 16
#
# Added child to OPEN:
# Node:
# 4 2 6
# 1 8 3
# 7 5 *
# g = 6, h = 10, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 4 *
# 2 8 6
# 7 5 3
# g = 6, h = 10, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 42, CLOSED size: 53
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 1 * 4
# 2 8 6
# 7 5 3
# g = 7, h = 9, f = 16
#
# Child 2:
# 1 4 6
# 2 8 *
# 7 5 3
# g = 7, h = 11, f = 18
#
# Added child to OPEN:
# Node:
# 1 * 4
# 2 8 6
# 7 5 3
# g = 7, h = 9, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 4 6
# 2 8 3
# 7 5 *
# g = 6, h = 10, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 42, CLOSED size: 54
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 1 4 6
# 2 8 3
# 7 * 5
# g = 7, h = 9, f = 16
#
# Child 2:
# 1 4 6
# 2 8 *
# 7 5 3
# g = 7, h = 11, f = 18
#
# Added child to OPEN:
# Node:
# 1 4 6
# 2 8 3
# 7 * 5
# g = 7, h = 9, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 4 2 1
# 8 6 *
# 7 5 3
# g = 7, h = 9, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 42, CLOSED size: 55
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 4 2 1
# 8 * 6
# 7 5 3
# g = 8, h = 10, f = 18
#
# Child 2:
# 4 2 *
# 8 6 1
# 7 5 3
# g = 8, h = 10, f = 18
#
# Child 3:
# 4 2 1
# 8 6 3
# 7 5 *
# g = 8, h = 8, f = 16
#
# Added child to OPEN:
# Node:
# 4 2 *
# 8 6 1
# 7 5 3
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 4 2 1
# 8 6 3
# 7 5 *
# g = 8, h = 8, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 6 *
# 2 4 3
# 7 8 5
# g = 8, h = 8, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 43, CLOSED size: 56
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 1 * 6
# 2 4 3
# 7 8 5
# g = 9, h = 9, f = 18
#
# Child 2:
# 1 6 3
# 2 4 *
# 7 8 5
# g = 9, h = 7, f = 16
#
# Added child to OPEN:
# Node:
# 1 6 3
# 2 4 *
# 7 8 5
# g = 9, h = 7, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 6 8
# * 2 4
# 7 5 3
# g = 7, h = 9, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 43, CLOSED size: 57
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 6 8
# 2 * 4
# 7 5 3
# g = 8, h = 10, f = 18
#
# Child 2:
# * 6 8
# 1 2 4
# 7 5 3
# g = 8, h = 10, f = 18
#
# Child 3:
# 1 6 8
# 7 2 4
# * 5 3
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# * 6 8
# 1 2 4
# 7 5 3
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 1 6 8
# 7 2 4
# * 5 3
# g = 8, h = 10, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 * 8
# 2 6 4
# 7 5 3
# g = 7, h = 9, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 44, CLOSED size: 58
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 8 *
# 2 6 4
# 7 5 3
# g = 8, h = 8, f = 16
#
# Child 2:
# * 1 8
# 2 6 4
# 7 5 3
# g = 8, h = 10, f = 18
#
# Child 3:
# 1 6 8
# 2 * 4
# 7 5 3
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 1 8 *
# 2 6 4
# 7 5 3
# g = 8, h = 8, f = 16
#
# Added child to OPEN:
# Node:
# * 1 8
# 2 6 4
# 7 5 3
# g = 8, h = 10, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 6 8
# 2 4 3
# 7 * 5
# g = 7, h = 9, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 45, CLOSED size: 59
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 6 8
# 2 4 3
# 7 5 *
# g = 8, h = 10, f = 18
#
# Child 2:
# 1 6 8
# 2 4 3
# * 7 5
# g = 8, h = 10, f = 18
#
# Child 3:
# 1 6 8
# 2 * 3
# 7 4 5
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 1 6 8
# 2 4 3
# * 7 5
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 1 6 8
# 2 * 3
# 7 4 5
# g = 8, h = 10, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 8 1
# 4 6 3
# 7 * 5
# g = 7, h = 9, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 46, CLOSED size: 60
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 8 1
# 4 6 3
# 7 5 *
# g = 8, h = 10, f = 18
#
# Child 2:
# 2 8 1
# 4 6 3
# * 7 5
# g = 8, h = 10, f = 18
#
# Child 3:
# 2 8 1
# 4 * 3
# 7 6 5
# g = 8, h = 8, f = 16
#
# Added child to OPEN:
# Node:
# 2 8 1
# 4 6 3
# * 7 5
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 2 8 1
# 4 * 3
# 7 6 5
# g = 8, h = 8, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 4 2 *
# 1 8 6
# 7 5 3
# g = 6, h = 10, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 47, CLOSED size: 61
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 4 * 2
# 1 8 6
# 7 5 3
# g = 7, h = 11, f = 18
#
# Child 2:
# 4 2 6
# 1 8 *
# 7 5 3
# g = 7, h = 11, f = 18
#
# Added child to OPEN:
# Node:
# 4 * 2
# 1 8 6
# 7 5 3
# g = 7, h = 11, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 4 2 6
# 1 8 3
# 7 5 *
# g = 6, h = 10, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 47, CLOSED size: 62
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 4 2 6
# 1 8 3
# 7 * 5
# g = 7, h = 9, f = 16
#
# Child 2:
# 4 2 6
# 1 8 *
# 7 5 3
# g = 7, h = 11, f = 18
#
# Added child to OPEN:
# Node:
# 4 2 6
# 1 8 3
# 7 * 5
# g = 7, h = 9, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 * 4
# 2 8 6
# 7 5 3
# g = 7, h = 9, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 47, CLOSED size: 63
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 4 *
# 2 8 6
# 7 5 3
# g = 8, h = 10, f = 18
#
# Child 2:
# * 1 4
# 2 8 6
# 7 5 3
# g = 8, h = 10, f = 18
#
# Child 3:
# 1 8 4
# 2 * 6
# 7 5 3
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# * 1 4
# 2 8 6
# 7 5 3
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 1 8 4
# 2 * 6
# 7 5 3
# g = 8, h = 10, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 4 6
# 2 8 3
# 7 * 5
# g = 7, h = 9, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 48, CLOSED size: 64
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 4 6
# 2 8 3
# 7 5 *
# g = 8, h = 10, f = 18
#
# Child 2:
# 1 4 6
# 2 8 3
# * 7 5
# g = 8, h = 10, f = 18
#
# Child 3:
# 1 4 6
# 2 * 3
# 7 8 5
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 1 4 6
# 2 8 3
# * 7 5
# g = 8, h = 10, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 4 2 1
# 8 6 3
# 7 5 *
# g = 8, h = 8, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 48, CLOSED size: 65
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 4 2 1
# 8 6 3
# 7 * 5
# g = 9, h = 7, f = 16
#
# Child 2:
# 4 2 1
# 8 6 *
# 7 5 3
# g = 9, h = 9, f = 18
#
# Added child to OPEN:
# Node:
# 4 2 1
# 8 6 3
# 7 * 5
# g = 9, h = 7, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 6 3
# 2 4 *
# 7 8 5
# g = 9, h = 7, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 48, CLOSED size: 66
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 6 3
# 2 * 4
# 7 8 5
# g = 10, h = 6, f = 16
#
# Child 2:
# 1 6 *
# 2 4 3
# 7 8 5
# g = 10, h = 8, f = 18
#
# Child 3:
# 1 6 3
# 2 4 5
# 7 8 *
# g = 10, h = 8, f = 18
#
# Added child to OPEN:
# Node:
# 1 6 3
# 2 * 4
# 7 8 5
# g = 10, h = 6, f = 16
#
# Added child to OPEN:
# Node:
# 1 6 3
# 2 4 5
# 7 8 *
# g = 10, h = 8, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 8 *
# 2 6 4
# 7 5 3
# g = 8, h = 8, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 49, CLOSED size: 67
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 1 * 8
# 2 6 4
# 7 5 3
# g = 9, h = 9, f = 18
#
# Child 2:
# 1 8 4
# 2 6 *
# 7 5 3
# g = 9, h = 9, f = 18
#
# Added child to OPEN:
# Node:
# 1 8 4
# 2 6 *
# 7 5 3
# g = 9, h = 9, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 8 1
# 4 * 3
# 7 6 5
# g = 8, h = 8, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 49, CLOSED size: 68
#
# n is not the goal state. Generating children...
#
# Generated 4 successors of n:
#
# Child 1:
# 2 8 1
# 4 3 *
# 7 6 5
# g = 9, h = 9, f = 18
#
# Child 2:
# 2 8 1
# * 4 3
# 7 6 5
# g = 9, h = 7, f = 16
#
# Child 3:
# 2 * 1
# 4 8 3
# 7 6 5
# g = 9, h = 7, f = 16
#
# Child 4:
# 2 8 1
# 4 6 3
# 7 * 5
# g = 9, h = 9, f = 18
#
# Added child to OPEN:
# Node:
# 2 8 1
# 4 3 *
# 7 6 5
# g = 9, h = 9, f = 18
#
# Added child to OPEN:
# Node:
# 2 8 1
# * 4 3
# 7 6 5
# g = 9, h = 7, f = 16
#
# Added child to OPEN:
# Node:
# 2 * 1
# 4 8 3
# 7 6 5
# g = 9, h = 7, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 4 2 6
# 1 8 3
# 7 * 5
# g = 7, h = 9, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 51, CLOSED size: 69
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 4 2 6
# 1 8 3
# 7 5 *
# g = 8, h = 10, f = 18
#
# Child 2:
# 4 2 6
# 1 8 3
# * 7 5
# g = 8, h = 10, f = 18
#
# Child 3:
# 4 2 6
# 1 * 3
# 7 8 5
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 4 2 6
# 1 8 3
# * 7 5
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 4 2 6
# 1 * 3
# 7 8 5
# g = 8, h = 10, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 4 2 1
# 8 6 3
# 7 * 5
# g = 9, h = 7, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 52, CLOSED size: 70
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 4 2 1
# 8 6 3
# 7 5 *
# g = 10, h = 8, f = 18
#
# Child 2:
# 4 2 1
# 8 6 3
# * 7 5
# g = 10, h = 8, f = 18
#
# Child 3:
# 4 2 1
# 8 * 3
# 7 6 5
# g = 10, h = 6, f = 16
#
# Added child to OPEN:
# Node:
# 4 2 1
# 8 6 3
# * 7 5
# g = 10, h = 8, f = 18
#
# Added child to OPEN:
# Node:
# 4 2 1
# 8 * 3
# 7 6 5
# g = 10, h = 6, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 6 3
# 2 * 4
# 7 8 5
# g = 10, h = 6, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 53, CLOSED size: 71
#
# n is not the goal state. Generating children...
#
# Generated 4 successors of n:
#
# Child 1:
# 1 6 3
# 2 4 *
# 7 8 5
# g = 11, h = 7, f = 18
#
# Child 2:
# 1 6 3
# * 2 4
# 7 8 5
# g = 11, h = 5, f = 16
#
# Child 3:
# 1 * 3
# 2 6 4
# 7 8 5
# g = 11, h = 5, f = 16
#
# Child 4:
# 1 6 3
# 2 8 4
# 7 * 5
# g = 11, h = 5, f = 16
#
# Added child to OPEN:
# Node:
# 1 6 3
# * 2 4
# 7 8 5
# g = 11, h = 5, f = 16
#
# Added child to OPEN:
# Node:
# 1 * 3
# 2 6 4
# 7 8 5
# g = 11, h = 5, f = 16
#
# Added child to OPEN:
# Node:
# 1 6 3
# 2 8 4
# 7 * 5
# g = 11, h = 5, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 8 1
# * 4 3
# 7 6 5
# g = 9, h = 7, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 55, CLOSED size: 72
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 8 1
# 4 * 3
# 7 6 5
# g = 10, h = 8, f = 18
#
# Child 2:
# * 8 1
# 2 4 3
# 7 6 5
# g = 10, h = 8, f = 18
#
# Child 3:
# 2 8 1
# 7 4 3
# * 6 5
# g = 10, h = 8, f = 18
#
# Added child to OPEN:
# Node:
# * 8 1
# 2 4 3
# 7 6 5
# g = 10, h = 8, f = 18
#
# Added child to OPEN:
# Node:
# 2 8 1
# 7 4 3
# * 6 5
# g = 10, h = 8, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 * 1
# 4 8 3
# 7 6 5
# g = 9, h = 7, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 56, CLOSED size: 73
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 *
# 4 8 3
# 7 6 5
# g = 10, h = 6, f = 16
#
# Child 2:
# * 2 1
# 4 8 3
# 7 6 5
# g = 10, h = 6, f = 16
#
# Child 3:
# 2 8 1
# 4 * 3
# 7 6 5
# g = 10, h = 8, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 *
# 4 8 3
# 7 6 5
# g = 10, h = 6, f = 16
#
# Added child to OPEN:
# Node:
# * 2 1
# 4 8 3
# 7 6 5
# g = 10, h = 6, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# 4 2 1
# 8 * 3
# 7 6 5
# g = 10, h = 6, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 57, CLOSED size: 74
#
# n is not the goal state. Generating children...
#
# Generated 4 successors of n:
#
# Child 1:
# 4 2 1
# 8 3 *
# 7 6 5
# g = 11, h = 7, f = 18
#
# Child 2:
# 4 2 1
# * 8 3
# 7 6 5
# g = 11, h = 7, f = 18
#
# Child 3:
# 4 * 1
# 8 2 3
# 7 6 5
# g = 11, h = 7, f = 18
#
# Child 4:
# 4 2 1
# 8 6 3
# 7 * 5
# g = 11, h = 7, f = 18
#
# Added child to OPEN:
# Node:
# 4 2 1
# 8 3 *
# 7 6 5
# g = 11, h = 7, f = 18
#
# Added child to OPEN:
# Node:
# 4 2 1
# * 8 3
# 7 6 5
# g = 11, h = 7, f = 18
#
# Added child to OPEN:
# Node:
# 4 * 1
# 8 2 3
# 7 6 5
# g = 11, h = 7, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 6 3
# * 2 4
# 7 8 5
# g = 11, h = 5, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 59, CLOSED size: 75
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 6 3
# 2 * 4
# 7 8 5
# g = 12, h = 6, f = 18
#
# Child 2:
# * 6 3
# 1 2 4
# 7 8 5
# g = 12, h = 6, f = 18
#
# Child 3:
# 1 6 3
# 7 2 4
# * 8 5
# g = 12, h = 6, f = 18
#
# Added child to OPEN:
# Node:
# * 6 3
# 1 2 4
# 7 8 5
# g = 12, h = 6, f = 18
#
# Added child to OPEN:
# Node:
# 1 6 3
# 7 2 4
# * 8 5
# g = 12, h = 6, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 * 3
# 2 6 4
# 7 8 5
# g = 11, h = 5, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 60, CLOSED size: 76
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 3 *
# 2 6 4
# 7 8 5
# g = 12, h = 6, f = 18
#
# Child 2:
# * 1 3
# 2 6 4
# 7 8 5
# g = 12, h = 6, f = 18
#
# Child 3:
# 1 6 3
# 2 * 4
# 7 8 5
# g = 12, h = 6, f = 18
#
# Added child to OPEN:
# Node:
# 1 3 *
# 2 6 4
# 7 8 5
# g = 12, h = 6, f = 18
#
# Added child to OPEN:
# Node:
# * 1 3
# 2 6 4
# 7 8 5
# g = 12, h = 6, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 6 3
# 2 8 4
# 7 * 5
# g = 11, h = 5, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 61, CLOSED size: 77
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 6 3
# 2 8 4
# 7 5 *
# g = 12, h = 6, f = 18
#
# Child 2:
# 1 6 3
# 2 8 4
# * 7 5
# g = 12, h = 6, f = 18
#
# Child 3:
# 1 6 3
# 2 * 4
# 7 8 5
# g = 12, h = 6, f = 18
#
# Added child to OPEN:
# Node:
# 1 6 3
# 2 8 4
# 7 5 *
# g = 12, h = 6, f = 18
#
# Added child to OPEN:
# Node:
# 1 6 3
# 2 8 4
# * 7 5
# g = 12, h = 6, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 *
# 4 8 3
# 7 6 5
# g = 10, h = 6, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 62, CLOSED size: 78
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 * 1
# 4 8 3
# 7 6 5
# g = 11, h = 7, f = 18
#
# Child 2:
# 2 1 3
# 4 8 *
# 7 6 5
# g = 11, h = 5, f = 16
#
# Added child to OPEN:
# Node:
# 2 1 3
# 4 8 *
# 7 6 5
# g = 11, h = 5, f = 16
#
#
# Selected node with smallest f from OPEN:
# n:
# * 2 1
# 4 8 3
# 7 6 5
# g = 10, h = 6, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 62, CLOSED size: 79
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 * 1
# 4 8 3
# 7 6 5
# g = 11, h = 7, f = 18
#
# Child 2:
# 4 2 1
# * 8 3
# 7 6 5
# g = 11, h = 7, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 3
# 4 8 *
# 7 6 5
# g = 11, h = 5, f = 16
#
# Moved n from OPEN to CLOSED.
# OPEN size: 61, CLOSED size: 80
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 3
# 4 * 8
# 7 6 5
# g = 12, h = 6, f = 18
#
# Child 2:
# 2 1 *
# 4 8 3
# 7 6 5
# g = 12, h = 6, f = 18
#
# Child 3:
# 2 1 3
# 4 8 5
# 7 6 *
# g = 12, h = 6, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 3
# 4 * 8
# 7 6 5
# g = 12, h = 6, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 3
# 4 8 5
# 7 6 *
# g = 12, h = 6, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 4 5 *
# 7 3 8
# g = 3, h = 15, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 62, CLOSED size: 81
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 6
# 4 * 5
# 7 3 8
# g = 4, h = 14, f = 18
#
# Child 2:
# 2 1 *
# 4 5 6
# 7 3 8
# g = 4, h = 14, f = 18
#
# Child 3:
# 2 1 6
# 4 5 8
# 7 3 *
# g = 4, h = 14, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 6
# 4 * 5
# 7 3 8
# g = 4, h = 14, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 *
# 4 5 6
# 7 3 8
# g = 4, h = 14, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# * 5 8
# 4 7 3
# g = 3, h = 15, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 63, CLOSED size: 82
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 6
# 5 * 8
# 4 7 3
# g = 4, h = 16, f = 20
#
# Child 2:
# * 1 6
# 2 5 8
# 4 7 3
# g = 4, h = 16, f = 20
#
# Child 3:
# 2 1 6
# 4 5 8
# * 7 3
# g = 4, h = 14, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 6
# 5 * 8
# 4 7 3
# g = 4, h = 16, f = 20
#
# Added child to OPEN:
# Node:
# * 1 6
# 2 5 8
# 4 7 3
# g = 4, h = 16, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 7 4 8
# 5 3 *
# g = 4, h = 14, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 64, CLOSED size: 83
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 1 6
# 7 4 8
# 5 * 3
# g = 5, h = 13, f = 18
#
# Child 2:
# 2 1 6
# 7 4 *
# 5 3 8
# g = 5, h = 15, f = 20
#
# Added child to OPEN:
# Node:
# 2 1 6
# 7 4 *
# 5 3 8
# g = 5, h = 15, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 7 * 8
# 5 4 3
# g = 4, h = 14, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 64, CLOSED size: 84
#
# n is not the goal state. Generating children...
#
# Generated 4 successors of n:
#
# Child 1:
# 2 1 6
# 7 8 *
# 5 4 3
# g = 5, h = 13, f = 18
#
# Child 2:
# 2 1 6
# * 7 8
# 5 4 3
# g = 5, h = 15, f = 20
#
# Child 3:
# 2 * 6
# 7 1 8
# 5 4 3
# g = 5, h = 15, f = 20
#
# Child 4:
# 2 1 6
# 7 4 8
# 5 * 3
# g = 5, h = 13, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 6
# 7 8 *
# 5 4 3
# g = 5, h = 13, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 6
# * 7 8
# 5 4 3
# g = 5, h = 15, f = 20
#
# Added child to OPEN:
# Node:
# 2 * 6
# 7 1 8
# 5 4 3
# g = 5, h = 15, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 8 1
# 4 5 6
# 7 * 3
# g = 5, h = 13, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 66, CLOSED size: 85
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 8 1
# 4 5 6
# 7 3 *
# g = 6, h = 14, f = 20
#
# Child 2:
# 2 8 1
# 4 5 6
# * 7 3
# g = 6, h = 14, f = 20
#
# Child 3:
# 2 8 1
# 4 * 6
# 7 5 3
# g = 6, h = 12, f = 18
#
# Added child to OPEN:
# Node:
# 2 8 1
# 4 5 6
# 7 3 *
# g = 6, h = 14, f = 20
#
# Added child to OPEN:
# Node:
# 2 8 1
# 4 5 6
# * 7 3
# g = 6, h = 14, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# * 1 6
# 2 8 3
# 4 7 5
# g = 6, h = 12, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 67, CLOSED size: 86
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 1 * 6
# 2 8 3
# 4 7 5
# g = 7, h = 11, f = 18
#
# Child 2:
# 2 1 6
# * 8 3
# 4 7 5
# g = 7, h = 11, f = 18
#
# Added child to OPEN:
# Node:
# 1 * 6
# 2 8 3
# 4 7 5
# g = 7, h = 11, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 4 3 5
# 7 8 *
# g = 6, h = 12, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 67, CLOSED size: 87
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 1 6
# 4 3 5
# 7 * 8
# g = 7, h = 13, f = 20
#
# Child 2:
# 2 1 6
# 4 3 *
# 7 8 5
# g = 7, h = 11, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 6
# 4 3 5
# 7 * 8
# g = 7, h = 13, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 6 8
# 4 * 1
# 7 5 3
# g = 4, h = 14, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 67, CLOSED size: 88
#
# n is not the goal state. Generating children...
#
# Generated 4 successors of n:
#
# Child 1:
# 2 6 8
# 4 1 *
# 7 5 3
# g = 5, h = 13, f = 18
#
# Child 2:
# 2 6 8
# * 4 1
# 7 5 3
# g = 5, h = 13, f = 18
#
# Child 3:
# 2 * 8
# 4 6 1
# 7 5 3
# g = 5, h = 13, f = 18
#
# Child 4:
# 2 6 8
# 4 5 1
# 7 * 3
# g = 5, h = 15, f = 20
#
# Added child to OPEN:
# Node:
# 2 6 8
# * 4 1
# 7 5 3
# g = 5, h = 13, f = 18
#
# Added child to OPEN:
# Node:
# 2 * 8
# 4 6 1
# 7 5 3
# g = 5, h = 13, f = 18
#
# Added child to OPEN:
# Node:
# 2 6 8
# 4 5 1
# 7 * 3
# g = 5, h = 15, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 4 2 6
# 7 1 8
# * 5 3
# g = 4, h = 14, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 69, CLOSED size: 89
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 4 2 6
# 7 1 8
# 5 * 3
# g = 5, h = 15, f = 20
#
# Child 2:
# 4 2 6
# * 1 8
# 7 5 3
# g = 5, h = 13, f = 18
#
# Added child to OPEN:
# Node:
# 4 2 6
# 7 1 8
# 5 * 3
# g = 5, h = 15, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 4 6
# 2 5 8
# 7 * 3
# g = 5, h = 13, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 69, CLOSED size: 90
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 4 6
# 2 5 8
# 7 3 *
# g = 6, h = 14, f = 20
#
# Child 2:
# 1 4 6
# 2 5 8
# * 7 3
# g = 6, h = 14, f = 20
#
# Child 3:
# 1 4 6
# 2 * 8
# 7 5 3
# g = 6, h = 12, f = 18
#
# Added child to OPEN:
# Node:
# 1 4 6
# 2 5 8
# 7 3 *
# g = 6, h = 14, f = 20
#
# Added child to OPEN:
# Node:
# 1 4 6
# 2 5 8
# * 7 3
# g = 6, h = 14, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 4 2 1
# 7 8 6
# * 5 3
# g = 6, h = 12, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 70, CLOSED size: 91
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 4 2 1
# 7 8 6
# 5 * 3
# g = 7, h = 13, f = 20
#
# Child 2:
# 4 2 1
# * 8 6
# 7 5 3
# g = 7, h = 11, f = 18
#
# Added child to OPEN:
# Node:
# 4 2 1
# 7 8 6
# 5 * 3
# g = 7, h = 13, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 8 *
# 4 6 1
# 7 5 3
# g = 6, h = 12, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 70, CLOSED size: 92
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 * 8
# 4 6 1
# 7 5 3
# g = 7, h = 13, f = 20
#
# Child 2:
# 2 8 1
# 4 6 *
# 7 5 3
# g = 7, h = 11, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# * 8 1
# 2 4 6
# 7 5 3
# g = 6, h = 12, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 69, CLOSED size: 93
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 8 * 1
# 2 4 6
# 7 5 3
# g = 7, h = 11, f = 18
#
# Child 2:
# 2 8 1
# * 4 6
# 7 5 3
# g = 7, h = 11, f = 18
#
# Added child to OPEN:
# Node:
# 8 * 1
# 2 4 6
# 7 5 3
# g = 7, h = 11, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 8 1
# 7 4 6
# * 5 3
# g = 6, h = 12, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 69, CLOSED size: 94
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 8 1
# 7 4 6
# 5 * 3
# g = 7, h = 13, f = 20
#
# Child 2:
# 2 8 1
# * 4 6
# 7 5 3
# g = 7, h = 11, f = 18
#
# Added child to OPEN:
# Node:
# 2 8 1
# 7 4 6
# 5 * 3
# g = 7, h = 13, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 8 3 *
# 4 7 5
# g = 7, h = 11, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 69, CLOSED size: 95
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 6
# 8 * 3
# 4 7 5
# g = 8, h = 10, f = 18
#
# Child 2:
# 2 1 *
# 8 3 6
# 4 7 5
# g = 8, h = 10, f = 18
#
# Child 3:
# 2 1 6
# 8 3 5
# 4 7 *
# g = 8, h = 12, f = 20
#
# Added child to OPEN:
# Node:
# 2 1 *
# 8 3 6
# 4 7 5
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 6
# 8 3 5
# 4 7 *
# g = 8, h = 12, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 * 6
# 8 1 3
# 4 7 5
# g = 7, h = 11, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 70, CLOSED size: 96
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 6 *
# 8 1 3
# 4 7 5
# g = 8, h = 10, f = 18
#
# Child 2:
# * 2 6
# 8 1 3
# 4 7 5
# g = 8, h = 10, f = 18
#
# Child 3:
# 2 1 6
# 8 * 3
# 4 7 5
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 2 6 *
# 8 1 3
# 4 7 5
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# * 2 6
# 8 1 3
# 4 7 5
# g = 8, h = 10, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 8 7 3
# 4 * 5
# g = 7, h = 11, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 71, CLOSED size: 97
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 6
# 8 7 3
# 4 5 *
# g = 8, h = 12, f = 20
#
# Child 2:
# 2 1 6
# 8 7 3
# * 4 5
# g = 8, h = 10, f = 18
#
# Child 3:
# 2 1 6
# 8 * 3
# 4 7 5
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 6
# 8 7 3
# 4 5 *
# g = 8, h = 12, f = 20
#
# Added child to OPEN:
# Node:
# 2 1 6
# 8 7 3
# * 4 5
# g = 8, h = 10, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 * 1
# 4 3 6
# 7 8 5
# g = 7, h = 11, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 72, CLOSED size: 98
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 *
# 4 3 6
# 7 8 5
# g = 8, h = 10, f = 18
#
# Child 2:
# * 2 1
# 4 3 6
# 7 8 5
# g = 8, h = 10, f = 18
#
# Child 3:
# 2 3 1
# 4 * 6
# 7 8 5
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# * 2 1
# 4 3 6
# 7 8 5
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 2 3 1
# 4 * 6
# 7 8 5
# g = 8, h = 10, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 4 2 6
# * 1 3
# 7 8 5
# g = 7, h = 11, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 73, CLOSED size: 99
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 4 2 6
# 1 * 3
# 7 8 5
# g = 8, h = 10, f = 18
#
# Child 2:
# * 2 6
# 4 1 3
# 7 8 5
# g = 8, h = 10, f = 18
#
# Child 3:
# 4 2 6
# 7 1 3
# * 8 5
# g = 8, h = 12, f = 20
#
# Added child to OPEN:
# Node:
# 4 2 6
# 7 1 3
# * 8 5
# g = 8, h = 12, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 4 * 6
# 1 2 8
# 7 5 3
# g = 5, h = 13, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 73, CLOSED size: 100
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 4 6 *
# ...
# 2 4 *
# 7 6 5
# g = 13, h = 5, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 4 1 3
# 8 2 *
# 7 6 5
# g = 13, h = 5, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 122, CLOSED size: 198
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 4 1 3
# 8 * 2
# 7 6 5
# g = 14, h = 6, f = 20
#
# Child 2:
# 4 1 *
# 8 2 3
# 7 6 5
# g = 14, h = 6, f = 20
#
# Child 3:
# 4 1 3
# 8 2 5
# 7 6 *
# g = 14, h = 6, f = 20
#
# Added child to OPEN:
# Node:
# 4 1 3
# 8 * 2
# 7 6 5
# g = 14, h = 6, f = 20
#
# Added child to OPEN:
# Node:
# 4 1 3
# 8 2 5
# 7 6 *
# g = 14, h = 6, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 7 8 3
# 5 * 4
# g = 7, h = 11, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 123, CLOSED size: 199
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 6
# 7 8 3
# 5 4 *
# g = 8, h = 12, f = 20
#
# Child 2:
# 2 1 6
# 7 8 3
# * 5 4
# g = 8, h = 10, f = 18
#
# Child 3:
# 2 1 6
# 7 * 3
# 5 8 4
# g = 8, h = 12, f = 20
#
# Added child to OPEN:
# Node:
# 2 1 6
# 7 8 3
# * 5 4
# g = 8, h = 10, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 6
# 7 * 3
# 5 8 4
# g = 8, h = 12, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 6 3
# 2 8 *
# 4 7 5
# g = 9, h = 9, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 124, CLOSED size: 200
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 6 3
# 2 * 8
# 4 7 5
# g = 10, h = 10, f = 20
#
# Child 2:
# 1 6 *
# 2 8 3
# 4 7 5
# g = 10, h = 10, f = 20
#
# Child 3:
# 1 6 3
# 2 8 5
# 4 7 *
# g = 10, h = 10, f = 20
#
# Added child to OPEN:
# Node:
# 1 6 3
# 2 * 8
# 4 7 5
# g = 10, h = 10, f = 20
#
# Added child to OPEN:
# Node:
# 1 6 3
# 2 8 5
# 4 7 *
# g = 10, h = 10, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 8 3
# 4 6 *
# 7 1 5
# g = 9, h = 9, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 125, CLOSED size: 201
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 8 3
# 4 * 6
# 7 1 5
# g = 10, h = 10, f = 20
#
# Child 2:
# 2 8 *
# 4 6 3
# 7 1 5
# g = 10, h = 10, f = 20
#
# Child 3:
# 2 8 3
# 4 6 5
# 7 1 *
# g = 10, h = 10, f = 20
#
# Added child to OPEN:
# Node:
# 2 8 3
# 4 * 6
# 7 1 5
# g = 10, h = 10, f = 20
#
# Added child to OPEN:
# Node:
# 2 8 3
# 4 6 5
# 7 1 *
# g = 10, h = 10, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 8 3
# 2 6 *
# 7 4 5
# g = 11, h = 7, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 126, CLOSED size: 202
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 8 3
# 2 * 6
# 7 4 5
# g = 12, h = 8, f = 20
#
# Child 2:
# 1 8 *
# 2 6 3
# 7 4 5
# g = 12, h = 8, f = 20
#
# Child 3:
# 1 8 3
# 2 6 5
# 7 4 *
# g = 12, h = 8, f = 20
#
# Added child to OPEN:
# Node:
# 1 8 3
# 2 * 6
# 7 4 5
# g = 12, h = 8, f = 20
#
# Added child to OPEN:
# Node:
# 1 8 3
# 2 6 5
# 7 4 *
# g = 12, h = 8, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 4 2
# 8 * 6
# 7 5 3
# g = 10, h = 8, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 127, CLOSED size: 203
#
# n is not the goal state. Generating children...
#
# Generated 4 successors of n:
#
# Child 1:
# 1 4 2
# 8 6 *
# 7 5 3
# g = 11, h = 7, f = 18
#
# Child 2:
# 1 4 2
# * 8 6
# 7 5 3
# g = 11, h = 9, f = 20
#
# Child 3:
# 1 * 2
# 8 4 6
# 7 5 3
# g = 11, h = 7, f = 18
#
# Child 4:
# 1 4 2
# 8 5 6
# 7 * 3
# g = 11, h = 9, f = 20
#
# Added child to OPEN:
# Node:
# 1 4 2
# 8 6 *
# 7 5 3
# g = 11, h = 7, f = 18
#
# Added child to OPEN:
# Node:
# 1 * 2
# 8 4 6
# 7 5 3
# g = 11, h = 7, f = 18
#
# Added child to OPEN:
# Node:
# 1 4 2
# 8 5 6
# 7 * 3
# g = 11, h = 9, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 4
# 8 6 *
# 7 5 3
# g = 11, h = 7, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 129, CLOSED size: 204
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 4
# 8 * 6
# 7 5 3
# g = 12, h = 8, f = 20
#
# Child 2:
# 2 1 *
# 8 6 4
# 7 5 3
# g = 12, h = 6, f = 18
#
# Child 3:
# 2 1 4
# 8 6 3
# 7 5 *
# g = 12, h = 6, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 *
# 8 6 4
# 7 5 3
# g = 12, h = 6, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 4
# 8 6 3
# 7 5 *
# g = 12, h = 6, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 8 4
# 2 * 3
# 7 6 5
# g = 12, h = 6, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 130, CLOSED size: 205
#
# n is not the goal state. Generating children...
#
# Generated 4 successors of n:
#
# Child 1:
# 1 8 4
# 2 3 *
# 7 6 5
# g = 13, h = 7, f = 20
#
# Child 2:
# 1 8 4
# * 2 3
# 7 6 5
# g = 13, h = 5, f = 18
#
# Child 3:
# 1 * 4
# 2 8 3
# 7 6 5
# g = 13, h = 5, f = 18
#
# Child 4:
# 1 8 4
# 2 6 3
# 7 * 5
# g = 13, h = 7, f = 20
#
# Added child to OPEN:
# Node:
# 1 8 4
# 2 3 *
# 7 6 5
# g = 13, h = 7, f = 20
#
# Added child to OPEN:
# Node:
# 1 8 4
# * 2 3
# 7 6 5
# g = 13, h = 5, f = 18
#
# Added child to OPEN:
# Node:
# 1 * 4
# 2 8 3
# 7 6 5
# g = 13, h = 5, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 8 1 3
# 2 4 *
# 7 6 5
# g = 13, h = 5, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 132, CLOSED size: 206
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 8 1 3
# 2 * 4
# 7 6 5
# g = 14, h = 4, f = 18
#
# Child 2:
# 8 1 *
# 2 4 3
# 7 6 5
# g = 14, h = 6, f = 20
#
# Child 3:
# 8 1 3
# 2 4 5
# 7 6 *
# g = 14, h = 6, f = 20
#
# Added child to OPEN:
# Node:
# 8 1 3
# 2 * 4
# 7 6 5
# g = 14, h = 4, f = 18
#
# Added child to OPEN:
# Node:
# 8 1 3
# 2 4 5
# 7 6 *
# g = 14, h = 6, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 7 8 3
# * 5 4
# g = 8, h = 10, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 133, CLOSED size: 207
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 1 6
# 7 8 3
# 5 * 4
# g = 9, h = 11, f = 20
#
# Child 2:
# 2 1 6
# * 8 3
# 7 5 4
# g = 9, h = 9, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 6
# * 8 3
# 7 5 4
# g = 9, h = 9, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 4 2
# 8 6 *
# 7 5 3
# g = 11, h = 7, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 133, CLOSED size: 208
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 4 2
# 8 * 6
# 7 5 3
# g = 12, h = 8, f = 20
#
# Child 2:
# 1 4 *
# 8 6 2
# 7 5 3
# g = 12, h = 8, f = 20
#
# Child 3:
# 1 4 2
# 8 6 3
# 7 5 *
# g = 12, h = 6, f = 18
#
# Added child to OPEN:
# Node:
# 1 4 *
# 8 6 2
# 7 5 3
# g = 12, h = 8, f = 20
#
# Added child to OPEN:
# Node:
# 1 4 2
# 8 6 3
# 7 5 *
# g = 12, h = 6, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 * 2
# 8 4 6
# 7 5 3
# g = 11, h = 7, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 134, CLOSED size: 209
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 2 *
# 8 4 6
# 7 5 3
# g = 12, h = 6, f = 18
#
# Child 2:
# * 1 2
# 8 4 6
# 7 5 3
# g = 12, h = 8, f = 20
#
# Child 3:
# 1 4 2
# 8 * 6
# 7 5 3
# g = 12, h = 8, f = 20
#
# Added child to OPEN:
# Node:
# 1 2 *
# 8 4 6
# 7 5 3
# g = 12, h = 6, f = 18
#
# Added child to OPEN:
# Node:
# * 1 2
# 8 4 6
# 7 5 3
# g = 12, h = 8, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 *
# 8 6 4
# 7 5 3
# g = 12, h = 6, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 135, CLOSED size: 210
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 * 1
# 8 6 4
# 7 5 3
# g = 13, h = 7, f = 20
#
# Child 2:
# 2 1 4
# 8 6 *
# 7 5 3
# g = 13, h = 7, f = 20
#
# Added child to OPEN:
# Node:
# 2 * 1
# 8 6 4
# 7 5 3
# g = 13, h = 7, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 4
# 8 6 3
# 7 5 *
# g = 12, h = 6, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 135, CLOSED size: 211
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 2 1 4
# 8 6 3
# 7 * 5
# g = 13, h = 5, f = 18
#
# Child 2:
# 2 1 4
# 8 6 *
# 7 5 3
# g = 13, h = 7, f = 20
#
# Added child to OPEN:
# Node:
# 2 1 4
# 8 6 3
# 7 * 5
# g = 13, h = 5, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 8 4
# * 2 3
# 7 6 5
# g = 13, h = 5, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 135, CLOSED size: 212
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 8 4
# 2 * 3
# 7 6 5
# g = 14, h = 6, f = 20
#
# Child 2:
# * 8 4
# 1 2 3
# 7 6 5
# g = 14, h = 6, f = 20
#
# Child 3:
# 1 8 4
# 7 2 3
# * 6 5
# g = 14, h = 6, f = 20
#
# Added child to OPEN:
# Node:
# * 8 4
# 1 2 3
# 7 6 5
# g = 14, h = 6, f = 20
#
# Added child to OPEN:
# Node:
# 1 8 4
# 7 2 3
# * 6 5
# g = 14, h = 6, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 * 4
# 2 8 3
# 7 6 5
# g = 13, h = 5, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 136, CLOSED size: 213
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 4 *
# 2 8 3
# 7 6 5
# g = 14, h = 6, f = 20
#
# Child 2:
# * 1 4
# 2 8 3
# 7 6 5
# g = 14, h = 6, f = 20
#
# Child 3:
# 1 8 4
# 2 * 3
# 7 6 5
# g = 14, h = 6, f = 20
#
# Added child to OPEN:
# Node:
# 1 4 *
# 2 8 3
# 7 6 5
# g = 14, h = 6, f = 20
#
# Added child to OPEN:
# Node:
# * 1 4
# 2 8 3
# 7 6 5
# g = 14, h = 6, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 8 1 3
# 2 * 4
# 7 6 5
# g = 14, h = 4, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 137, CLOSED size: 214
#
# n is not the goal state. Generating children...
#
# Generated 4 successors of n:
#
# Child 1:
# 8 1 3
# 2 4 *
# 7 6 5
# g = 15, h = 5, f = 20
#
# Child 2:
# 8 1 3
# * 2 4
# 7 6 5
# g = 15, h = 3, f = 18
#
# Child 3:
# 8 * 3
# 2 1 4
# 7 6 5
# g = 15, h = 5, f = 20
#
# Child 4:
# 8 1 3
# 2 6 4
# 7 * 5
# g = 15, h = 5, f = 20
#
# Added child to OPEN:
# Node:
# 8 1 3
# * 2 4
# 7 6 5
# g = 15, h = 3, f = 18
#
# Added child to OPEN:
# Node:
# 8 * 3
# 2 1 4
# 7 6 5
# g = 15, h = 5, f = 20
#
# Added child to OPEN:
# Node:
# 8 1 3
# 2 6 4
# 7 * 5
# g = 15, h = 5, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# * 8 3
# 7 5 4
# g = 9, h = 9, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 139, CLOSED size: 215
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 6
# 8 * 3
# 7 5 4
# g = 10, h = 8, f = 18
#
# Child 2:
# * 1 6
# 2 8 3
# 7 5 4
# g = 10, h = 10, f = 20
#
# Child 3:
# 2 1 6
# 7 8 3
# * 5 4
# g = 10, h = 10, f = 20
#
# Added child to OPEN:
# Node:
# 2 1 6
# 8 * 3
# 7 5 4
# g = 10, h = 8, f = 18
#
# Added child to OPEN:
# Node:
# * 1 6
# 2 8 3
# 7 5 4
# g = 10, h = 10, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 4 2
# 8 6 3
# 7 5 *
# g = 12, h = 6, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 140, CLOSED size: 216
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 1 4 2
# 8 6 3
# 7 * 5
# g = 13, h = 5, f = 18
#
# Child 2:
# 1 4 2
# 8 6 *
# 7 5 3
# g = 13, h = 7, f = 20
#
# Added child to OPEN:
# Node:
# 1 4 2
# 8 6 3
# 7 * 5
# g = 13, h = 5, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 2 *
# 8 4 6
# 7 5 3
# g = 12, h = 6, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 140, CLOSED size: 217
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 1 * 2
# 8 4 6
# 7 5 3
# g = 13, h = 7, f = 20
#
# Child 2:
# 1 2 6
# 8 4 *
# 7 5 3
# g = 13, h = 7, f = 20
#
# Added child to OPEN:
# Node:
# 1 2 6
# 8 4 *
# 7 5 3
# g = 13, h = 7, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 4
# 8 6 3
# 7 * 5
# g = 13, h = 5, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 140, CLOSED size: 218
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 2 1 4
# 8 6 3
# 7 5 *
# g = 14, h = 6, f = 20
#
# Child 2:
# 2 1 4
# 8 6 3
# * 7 5
# g = 14, h = 6, f = 20
#
# Child 3:
# 2 1 4
# 8 * 3
# 7 6 5
# g = 14, h = 4, f = 18
#
# Added child to OPEN:
# Node:
# 2 1 4
# 8 6 3
# * 7 5
# g = 14, h = 6, f = 20
#
# Added child to OPEN:
# Node:
# 2 1 4
# 8 * 3
# 7 6 5
# g = 14, h = 4, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 8 1 3
# * 2 4
# 7 6 5
# g = 15, h = 3, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 141, CLOSED size: 219
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 8 1 3
# 2 * 4
# 7 6 5
# g = 16, h = 4, f = 20
#
# Child 2:
# * 1 3
# 8 2 4
# 7 6 5
# g = 16, h = 2, f = 18
#
# Child 3:
# 8 1 3
# 7 2 4
# * 6 5
# g = 16, h = 4, f = 20
#
# Added child to OPEN:
# Node:
# * 1 3
# 8 2 4
# 7 6 5
# g = 16, h = 2, f = 18
#
# Added child to OPEN:
# Node:
# 8 1 3
# 7 2 4
# * 6 5
# g = 16, h = 4, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 6
# 8 * 3
# 7 5 4
# g = 10, h = 8, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 142, CLOSED size: 220
#
# n is not the goal state. Generating children...
#
# Generated 4 successors of n:
#
# Child 1:
# 2 1 6
# 8 3 *
# 7 5 4
# g = 11, h = 9, f = 20
#
# Child 2:
# 2 1 6
# * 8 3
# 7 5 4
# g = 11, h = 9, f = 20
#
# Child 3:
# 2 * 6
# 8 1 3
# 7 5 4
# g = 11, h = 9, f = 20
#
# Child 4:
# 2 1 6
# 8 5 3
# 7 * 4
# g = 11, h = 9, f = 20
#
# Added child to OPEN:
# Node:
# 2 1 6
# 8 3 *
# 7 5 4
# g = 11, h = 9, f = 20
#
# Added child to OPEN:
# Node:
# 2 * 6
# 8 1 3
# 7 5 4
# g = 11, h = 9, f = 20
#
# Added child to OPEN:
# Node:
# 2 1 6
# 8 5 3
# 7 * 4
# g = 11, h = 9, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 4 2
# 8 6 3
# 7 * 5
# g = 13, h = 5, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 144, CLOSED size: 221
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 4 2
# 8 6 3
# 7 5 *
# g = 14, h = 6, f = 20
#
# Child 2:
# 1 4 2
# 8 6 3
# * 7 5
# g = 14, h = 6, f = 20
#
# Child 3:
# 1 4 2
# 8 * 3
# 7 6 5
# g = 14, h = 4, f = 18
#
# Added child to OPEN:
# Node:
# 1 4 2
# 8 6 3
# * 7 5
# g = 14, h = 6, f = 20
#
# Added child to OPEN:
# Node:
# 1 4 2
# 8 * 3
# 7 6 5
# g = 14, h = 4, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 2 1 4
# 8 * 3
# 7 6 5
# g = 14, h = 4, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 145, CLOSED size: 222
#
# n is not the goal state. Generating children...
#
# Generated 4 successors of n:
#
# Child 1:
# 2 1 4
# 8 3 *
# 7 6 5
# g = 15, h = 5, f = 20
#
# Child 2:
# 2 1 4
# * 8 3
# 7 6 5
# g = 15, h = 5, f = 20
#
# Child 3:
# 2 * 4
# 8 1 3
# 7 6 5
# g = 15, h = 5, f = 20
#
# Child 4:
# 2 1 4
# 8 6 3
# 7 * 5
# g = 15, h = 5, f = 20
#
# Added child to OPEN:
# Node:
# 2 1 4
# 8 3 *
# 7 6 5
# g = 15, h = 5, f = 20
#
# Added child to OPEN:
# Node:
# 2 1 4
# * 8 3
# 7 6 5
# g = 15, h = 5, f = 20
#
# Added child to OPEN:
# Node:
# 2 * 4
# 8 1 3
# 7 6 5
# g = 15, h = 5, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# * 1 3
# 8 2 4
# 7 6 5
# g = 16, h = 2, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 147, CLOSED size: 223
#
# n is not the goal state. Generating children...
#
# Generated 2 successors of n:
#
# Child 1:
# 1 * 3
# 8 2 4
# 7 6 5
# g = 17, h = 1, f = 18
#
# Child 2:
# 8 1 3
# * 2 4
# 7 6 5
# g = 17, h = 3, f = 20
#
# Added child to OPEN:
# Node:
# 1 * 3
# 8 2 4
# 7 6 5
# g = 17, h = 1, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 4 2
# 8 * 3
# 7 6 5
# g = 14, h = 4, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 147, CLOSED size: 224
#
# n is not the goal state. Generating children...
#
# Generated 4 successors of n:
#
# Child 1:
# 1 4 2
# 8 3 *
# 7 6 5
# g = 15, h = 5, f = 20
#
# Child 2:
# 1 4 2
# * 8 3
# 7 6 5
# g = 15, h = 5, f = 20
#
# Child 3:
# 1 * 2
# 8 4 3
# 7 6 5
# g = 15, h = 3, f = 18
#
# Child 4:
# 1 4 2
# 8 6 3
# 7 * 5
# g = 15, h = 5, f = 20
#
# Added child to OPEN:
# Node:
# 1 4 2
# 8 3 *
# 7 6 5
# g = 15, h = 5, f = 20
#
# Added child to OPEN:
# Node:
# 1 4 2
# * 8 3
# 7 6 5
# g = 15, h = 5, f = 20
#
# Added child to OPEN:
# Node:
# 1 * 2
# 8 4 3
# 7 6 5
# g = 15, h = 3, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 * 3
# 8 2 4
# 7 6 5
# g = 17, h = 1, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 149, CLOSED size: 225
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 3 *
# 8 2 4
# 7 6 5
# g = 18, h = 2, f = 20
#
# Child 2:
# * 1 3
# 8 2 4
# 7 6 5
# g = 18, h = 2, f = 20
#
# Child 3:
# 1 2 3
# 8 * 4
# 7 6 5
# g = 18, h = 0, f = 18
#
# Added child to OPEN:
# Node:
# 1 3 *
# 8 2 4
# 7 6 5
# g = 18, h = 2, f = 20
#
# Added child to OPEN:
# Node:
# 1 2 3
# 8 * 4
# 7 6 5
# g = 18, h = 0, f = 18
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 * 2
# 8 4 3
# 7 6 5
# g = 15, h = 3, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 150, CLOSED size: 226
#
# n is not the goal state. Generating children...
#
# Generated 3 successors of n:
#
# Child 1:
# 1 2 *
# 8 4 3
# 7 6 5
# g = 16, h = 2, f = 18
#
# Child 2:
# * 1 2
# 8 4 3
# 7 6 5
# g = 16, h = 4, f = 20
#
# Child 3:
# 1 4 2
# 8 * 3
# 7 6 5
# g = 16, h = 4, f = 20
#
# Added child to OPEN:
# Node:
# 1 2 *
# 8 4 3
# 7 6 5
# g = 16, h = 2, f = 18
#
# Added child to OPEN:
# Node:
# * 1 2
# 8 4 3
# 7 6 5
# g = 16, h = 4, f = 20
#
#
# Selected node with smallest f from OPEN:
# n:
# 1 2 3
# 8 * 4
# 7 6 5
# g = 18, h = 0, f = 18
#
# Moved n from OPEN to CLOSED.
# OPEN size: 151, CLOSED size: 227
#
#
# Solution Found!
# Number of moves: 18
#
# Step 0 (g=0, h=12, f=12):
# 2 1 6
# 4 * 8
# 7 5 3
#
# Step 1 (g=1, h=11, f=12):
# 2 1 6
# 4 8 *
# 7 5 3
#
# Step 2 (g=2, h=10, f=12):
# 2 1 *
# 4 8 6
# 7 5 3
#
# Step 3 (g=3, h=11, f=14):
# 2 * 1
# 4 8 6
# 7 5 3
#
# Step 4 (g=4, h=12, f=16):
# 2 8 1
# 4 * 6
# 7 5 3
#
# Step 5 (g=5, h=11, f=16):
# 2 8 1
# 4 6 *
# 7 5 3
#
# Step 6 (g=6, h=10, f=16):
# 2 8 1
# 4 6 3
# 7 5 *
#
# Step 7 (g=7, h=9, f=16):
# 2 8 1
# 4 6 3
# 7 * 5
#
# Step 8 (g=8, h=8, f=16):
# 2 8 1
# 4 * 3
# 7 6 5
#
# Step 9 (g=9, h=7, f=16):
# 2 8 1
# * 4 3
# 7 6 5
#
# Step 10 (g=10, h=8, f=18):
# * 8 1
# 2 4 3
# 7 6 5
#
# Step 11 (g=11, h=7, f=18):
# 8 * 1
# 2 4 3
# 7 6 5
#
# Step 12 (g=12, h=6, f=18):
# 8 1 *
# 2 4 3
# 7 6 5
#
# Step 13 (g=13, h=5, f=18):
# 8 1 3
# 2 4 *
# 7 6 5
#
# Step 14 (g=14, h=4, f=18):
# 8 1 3
# 2 * 4
# 7 6 5
#
# Step 15 (g=15, h=3, f=18):
# 8 1 3
# * 2 4
# 7 6 5
#
# Step 16 (g=16, h=2, f=18):
# * 1 3
# 8 2 4
# 7 6 5
#
# Step 17 (g=17, h=1, f=18):
# 1 * 3
# 8 2 4
# 7 6 5
#
# Step 18 (g=18, h=0, f=18):
# 1 2 3
# 8 * 4
# 7 6 5
